# %%
# conditional statements in python
1. pyhton havee 3 types of conditional statements
2. if condition
3. elif condition
4. else condition
```python
if (logic):
    statements
```
```pyhton if ,else
if(logic):
    statements
else:
    statements
```
```python if,elif,else
if(logic):
    statments
elif(logic):
    statements
else:
    statements
```

# %%
# wap to check if a no. is even or odd
num=int(input("Please enter a no. :"))
if (num%2==0):
    print(num,"is even")
else:
    print(num,"is odd")
# Out:
# Please enter a no. : 2
# 2 is even

# %%
# wap to check if a no. +ve or -ve or zero
num=int(input("Enter a no.:"))
if (num<0):
    print(num,"is negative")
elif(num==0):
    print(num,"is zero")
else:
    print(num,"is postitive")
# Out:
# Enter a no.: -6
# -6 is negative

# %%
#wap for the grades of sudents
mark=int(input("Enter marks:"))
if (mark>=80 and mark<=100):
    print("A grade")
elif(mark>=60 and mark<80):
    print("B grade")
elif(mark>=40 and mark<60):
    print("C grade")
elif(mark>=25 and mark<40):
    print("D grade")
elif(mark>=0 and mark<25):
    print("FAIL")
else:
    print("Please enter valid marks")
# Out:
# Enter marks: 100
# A grade

# %%
#wap to find largest no. from three no.s
#wap to check login credentials using conditonal statements
#write a calculator program using conditional statements

# %%
# WAP to find the largest number among three numbers

a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
c = float(input("Enter third number: "))
if a >= b and a >= c:
    largest = a
elif b >= a and b >= c:
    largest = b
else:
    largest = c
print("The largest number is:", largest)
# Out:
# Enter first number:  12
# Enter second number:  13
# Enter third number:  14
# The largest number is: 14.0

# %%
# Program to check login credentials using conditional statements

correct_username = "admin"
correct_password = "12345"
username = input("Enter your username: ")
password = input("Enter your password: ")
if username == correct_username and password == correct_password:
    print("Login successful! Welcome", username)
elif username != correct_username and password == correct_password:
    print("Invalid username!")
elif username == correct_username and password != correct_password:
    print("Incorrect password!")
else:
    print("Both username and password are incorrect!")
# Out:
# Enter your username:  admin
# Enter your password:  12345
# Login successful! Welcome admin

# %%
# Simple Calculator using Conditional Statements

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
print("Select operation:")
print("1. Addition (+)")
print("2. Subtraction (-)")
print("3. Multiplication (*)")
print("4. Division (/)")
choice = input("Enter your choice (+, -, *, /): ")
if choice == '+':
    print("Result:", num1 + num2)
elif choice == '-':
    print("Result:", num1 - num2)
elif choice == '*':
    print("Result:", num1 * num2)
elif choice == '/':
    if num2 != 0:
        print("Result:", num1 / num2)
    else:
        print("Error! Division by zero is not allowed.")
else:
    print("Invalid input! Please select a valid operation.")
# Out:
# Enter first number:  65.6
# Enter second number:  43.9
# Select operation:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# Enter your choice (+, -, *, /):  /
# Result: 1.4943052391799543

# %%
'''
#wap to find the even number with below conditions
 1. if the no. in b/w 0 to 9 then result is 1 digit number
 2.if the no. in b/w 10 to 99 then the result is 2 digit number
3.if the number is b/w 100 to 999 then result is 3 digit number
4.if the number is b/w 1000 to 9999 then result is 4 digit number
5. if other than above even number than result is- weird digit number
'''
# WAP to find the even number with given conditions

num = int(input("Enter a number: "))

if num % 2 == 0:  # Check if number is even
    if 0 <= num <= 9:
        print("1 digit number")
    elif 10 <= num <= 99:
        print("2 digit number")
    elif 100 <= num <= 999:
        print("3 digit number")
    elif 1000 <= num <= 9999:
        print("4 digit number")
    else:
        print("weird digit number")
else:
    print("The number is not even.")
# Out:
# Enter a number:  100000
# weird digit number
